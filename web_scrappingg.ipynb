# %% [markdown]
# <a href="https://colab.research.google.com/github/thangpro1242002/web_scrapping/blob/main/web_scrappingg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import os

# %% [markdown]
# #Cách lấy html từ url tương ứng

# %%
from urllib.request import urlopen

r = urlopen('https://vietnamnet.vn/')
print(r.read())
# Out:
# b'<!DOCTYPE html><html lang="vi"><head><script language="javascript" src="https://vnn-res.vgcloud.vn/ResV9/js/startup-2019-v003.js">\xc2\xa0</script><script type="text/javascript">\n       var globalads_off=false;\n     </script><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><link type="image/x-icon" href="https://vnn-res.vgcloud.vn/ResV9/images/faviconvnn2018.ico" rel="shortcut icon" /><meta name="viewport" content="width=device-width, initial-scale=1.0" /><title>B\xc3\xa1o VietNamNet - Tin t\xe1\xbb\xa9c online, tin nhanh Vi\xe1\xbb\x87t Nam v\xc3\xa0 th\xe1\xba\xbf gi\xe1\xbb\x9bi</title><meta name="description" content="\xc4\x90\xe1\xbb\x8dc b\xc3\xa1o \xc4\x91i\xe1\xbb\x87n t\xe1\xbb\xad VietNamNet, c\xe1\xba\xadp nh\xe1\xba\xadt tin nhanh Vi\xe1\xbb\x87t Nam v\xc3\xa0 th\xe1\xba\xbf gi\xe1\xbb\x9bi. S\xe1\xbb\xb1 ki\xe1\xbb\x87n, tin b\xc3\xa1o m\xe1\xbb\x9bi trong ng\xc3\xa0y, kinh t\xe1\xba\xbf, x\xc3\xa3 h\xe1\xbb\x99i, ph\xc3\xa1p lu\xe1\xba\xadt 24h q
# ...

# %% [markdown]
# #Cách lấy các url trong html

# %%
html = urlopen('https://vietnamnet.vn/')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /
#   https://vietnamnet.vn/vn/tet-nguyen-dan/
# https://vietnamnet.vn/vn/thoi-su/dai-hoi-dang-lan-thu-xiii/
# #
# /vn/tin-moi-nong/
# /vn/tin-tuc-24h/
# https://www.facebook.com/vietnamnet.vn
# https://www.youtube.com/vietnamnetofficial
# javascript:void(0)
# javascript:void(0)
# https://id.vietnamnet.vn/Home.html
# javascript:void(0)
# /
# /vn/thoi-su/chinh-tri/
# /vn/talkshow/
# /vn/thoi-su/
# /vn/thoi-su/chong-tham-nhung/
# /vn/thoi-su/quoc-hoi/
# /vn/thoi-su/an-toan-giao-thong/
# /vn/thoi-su/moi-truong/
# /vn/thoi-su/clip-nong/
# /vn/thoi-su/bhxh-bhyt/
# /vn/thoi-su/quoc-phong/
# /vn/kinh-doanh/
# /vn/kinh-doanh/tai-chinh/
# /vn/kinh-doanh/dau-tu/
# /vn/kinh-doanh/thi-truong/
# /vn/kinh-doanh/doanh-nhan/
# /vn/kinh-doanh/tu-van-tai-chinh/
# /vn/kinh-doanh/Amaccao/
# /vn/giai-tri/
# /vn/giai-tri/the-gioi-sao/
# /vn/giai-tri/thoi-trang/
# /vn/giai-tri/nhac/
# /vn/giai-tri/phim/
# /vn/giai-tri/truyen-hinh/
# /vn/giai-tri/sach/
# /vn/giai-tri/di-san-my-thuat-san-khau/
# ...
